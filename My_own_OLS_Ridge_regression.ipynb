# %% [markdown]
# <a href="https://colab.research.google.com/github/omkar123katare/Regularization/blob/main/My_own_OLS_Ridge_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OLS folrmula for ridge regression in simple linear regression

# %% [markdown]
# ![WhatsApp Image 2022-06-10 at 1.32.12 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # OLS folrmula for ridge regression for multiple linear regression

# %% [markdown]
# ![WhatsApp Image 2022-06-10 at 1.37.34 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-06-10 at 1.39.48 PM.jpeg](data:image/jpeg;base64,...)
