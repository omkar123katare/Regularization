# %% [markdown]
# <a href="https://colab.research.google.com/github/omkar123katare/Regularization/blob/main/Ridge_regression_using_gradirnt_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ridge regression usging Grdient Descent

# %% [markdown]
# ![WhatsApp Image 2022-06-10 at 1.48.31 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-06-10 at 1.51.57 PM.jpeg](data:image/jpeg;base64,...)
